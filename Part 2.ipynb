# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv")

# %%
df
# Out:
#     Country Code                                             Region  \
# 0            ABW                          Latin America & Caribbean
# 1            AFE                                                NaN
# 2            AFG  Middle East, North Africa, Afghanistan & Pakistan
# 3            AFW                                                NaN
# 4            AGO                                 Sub-Saharan Africa
# ..           ...                                                ...
# 260          XKX                              Europe & Central Asia
# 261          YEM  Middle East, North Africa, Afghanistan & Pakistan
# 262          ZAF                                 Sub-Saharan Africa
# 263          ZMB                                 Sub-Saharan Africa
# 264          ZWE                                 Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes  \
# ...

# %%
gender_counts = df['Region'].value_counts()
bar_width = 0.9
x=range(len(gender_counts.index))


plt.bar(gender_counts.index,gender_counts.values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Region')


plt.xticks(x,gender_counts.index,rotation=45)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (265, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   215 non-null    object
#  3   SpecialNotes  129 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      50
# SpecialNotes    136
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   215 non-null    object
#  3   SpecialNotes  129 non-null    object
#  4   TableName     265 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.6+ KB
